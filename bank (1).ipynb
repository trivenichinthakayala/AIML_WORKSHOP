# %%
#Manager: "Rahul, write a small program that takes input from the customer like their
#name, age, and account balance, and then
#displays a welcome me sage on the screen. This is to help you understand how our systems
#interact with users."

# intyerview qwuestion: here the above things are in the tuple or list format and also they are is
# a login and logout of employess this are in the format of what
#2. using an array concept here i have already defined the users
# can i print this users when ever i required
name="nadima"
print("hi",name,"welcome to SBI Bank")
a,b=input("enter your age and accountbalance").split()
print("age:",a,"accountbalance:",b)
# Out:
# hi nadima welcome to SBI Bank
# age: 19 accountbalance: 2000

# %%
s1,s2=input("Enter number of saving account and salary account")#.split()
print("Number of savings account:",s1)
print("Number of salary account:",s2)
# Out:
# Number of savings account: 3
# Number of salary account: 4
